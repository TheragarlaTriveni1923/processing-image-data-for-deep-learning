# %% [markdown]
# <a href="https://colab.research.google.com/github/TheragarlaTriveni1923/processing-image-data-for-deep-learning/blob/main/processing_image_data_for_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img=mpimg.imread('/content/dog image.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
print(img)
# Out:
# (121, 195, 3)
# [[[202 187 146]
#   [200 185 144]
#   [199 184 141]
#   ...
#   [ 53  40  34]
#   [ 47  36  30]
#   [ 46  35  29]]
#
#  [[201 186 145]
#   [199 184 143]
#   [198 183 140]
#   ...
#   [ 50  39  33]
#   [ 46  35  29]
#   [ 46  35  29]]
#
#  [[201 186 143]
#   [198 183 140]
#   [200 183 140]
#   ...
#   [ 48  38  29]
#   [ 45  35  26]
#   [ 44  34  25]]
#
#  ...
#
#  [[ 69  40  10]
#   [ 55  28   0]
#   [ 49  28   0]
#   ...
#   [ 61  88   0]
#   [ 64 105   3]
#   [ 68 106   3]]
#
#  [[ 47  12   0]
#   [ 51  20   0]
#   [ 50  29   2]
#   ...
#   [ 66  93   0]
#   [ 79 118  11]
#   [ 79 118  11]]
#
#  [[ 66  24  12]
#   [ 50  14   0]
#   [ 49  25   0]
#   ...
#   [ 83 108   7]
#   [ 88 122  10]
#   [ 86 123  10]]]

# %%
img_plot=plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img=Image.open('/content/dog image.jpeg')

# %%
img_resized=img.resize((200,200))

# %%
img_resized.save('dog_image_that_is_saved.jpg')

# %%
img=mpimg.imread("/content/dog_image_that_is_saved.jpg")
img_plot=plt.imshow(img)
plt.show()

# %%
print(img.shape)
# Out:
# (200, 200, 3)

# %%
import cv2
img=cv2.imread("/content/dog image.jpeg")

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
print(grayscale_image)
# Out:
# [[176 174 173 ...  40  35  34]
#  [175 173 172 ...  38  34  34]
#  [175 172 172 ...  36  33  32]
#  ...
#  [ 34  23  22 ...  59  70  71]
#  [ 12  18  23 ...  62  82  82]
#  [ 25  14  20 ...  75  85  85]]

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=195x121>

# %%
cv2.imwrite('dog_grayscale_image.jpg',grayscale_image)
# Out:
# True
